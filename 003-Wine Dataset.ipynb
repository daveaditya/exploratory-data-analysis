# %% [markdown]
# # Explorartory Data Analysis on Sklearn - Wine Dataset

# %% [markdown]
# ![Types of Wine](https://www.tippleanddram.com/blog/wp-content/uploads/2019/07/different-types-of-wine.jpg)

# %%
import numpy as np
import pandas as pd
from sklearn import datasets
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
wine_dataset = datasets.load_wine()

# %%
df = pd.DataFrame(wine_dataset['data'], columns=wine_dataset['feature_names'])
df.head()
# Out:
#    alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0    14.23        1.71  2.43               15.6      127.0           2.80
# 1    13.20        1.78  2.14               11.2      100.0           2.65
# 2    13.16        2.36  2.67               18.6      101.0           2.80
# 3    14.37        1.95  2.50               16.8      113.0           3.85
# 4    13.24        2.59  2.87               21.0      118.0           2.80
#
#    flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39             1.82             4.32  1.04
#
#    od280/od315_of_diluted_wines  proline
# ...

# %%
df['target'] = wine_dataset['target']

# %%
wine_dataset['target_names']
# Out:
# array(['class_0', 'class_1', 'class_2'], dtype='<U7')

# %%
print(wine_dataset['DESCR'])
# Out:
# .. _wine_dataset:
#
# Wine recognition dataset
# ------------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 178 (50 in each of three classes)
#     :Number of Attributes: 13 numeric, predictive attributes and the class
#     :Attribute Information:
#  		- Alcohol
#  		- Malic acid
#  		- Ash
# 		- Alcalinity of ash
#  		- Magnesium
# 		- Total phenols
#  		- Flavanoids
#  		- Nonflavanoid phenols
#  		- Proanthocyanins
# 		- Color intensity
#  		- Hue
#  		- OD280/OD315 of diluted wines
#  		- Proline
#
#     - class:
#             - class_0
#             - class_1
#             - class_2
#
#     :Summary Statistics:
#
#     ============================= ==== ===== ======= =====
#                                    Min   Max   Mean     SD
#     ============================= ==== ===== ======= =====
#     Alcohol:                      11.0  14.8    13.0   0.8
#     Malic Acid:                   0.74  5.80    2.34  1.12
# ...

# %% [markdown]
# There are 178 rows and 13 features in the dataset. The dataset is that of classification with three classes for the wines grown:
# - class_0
# - class_1
# - class_2

# %%
df.shape
# Out:
# (178, 14)

# %%
df.dtypes
# Out:
# alcohol                         float64
# malic_acid                      float64
# ash                             float64
# alcalinity_of_ash               float64
# magnesium                       float64
# total_phenols                   float64
# flavanoids                      float64
# nonflavanoid_phenols            float64
# proanthocyanins                 float64
# color_intensity                 float64
# hue                             float64
# od280/od315_of_diluted_wines    float64
# proline                         float64
# target                            int64
# dtype: object

# %% [markdown]
# Every feature in the dataset is of type `float64`.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178 entries, 0 to 177
# Data columns (total 14 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   alcohol                       178 non-null    float64
#  1   malic_acid                    178 non-null    float64
#  2   ash                           178 non-null    float64
#  3   alcalinity_of_ash             178 non-null    float64
#  4   magnesium                     178 non-null    float64
#  5   total_phenols                 178 non-null    float64
#  6   flavanoids                    178 non-null    float64
#  7   nonflavanoid_phenols          178 non-null    float64
#  8   proanthocyanins               178 non-null    float64
#  9   color_intensity               178 non-null    float64
#  10  hue                           178 non-null    float64
#  11  od280/od315_of_diluted_wines  178 non-null    float64
# ...

# %%
df.describe()
# Out:
#           alcohol  malic_acid         ash  alcalinity_of_ash   magnesium  \
# count  178.000000  178.000000  178.000000         178.000000  178.000000
# mean    13.000618    2.336348    2.366517          19.494944   99.741573
# std      0.811827    1.117146    0.274344           3.339564   14.282484
# min     11.030000    0.740000    1.360000          10.600000   70.000000
# 25%     12.362500    1.602500    2.210000          17.200000   88.000000
# 50%     13.050000    1.865000    2.360000          19.500000   98.000000
# 75%     13.677500    3.082500    2.557500          21.500000  107.000000
# max     14.830000    5.800000    3.230000          30.000000  162.000000
#
#        total_phenols  flavanoids  nonflavanoid_phenols  proanthocyanins  \
# count     178.000000  178.000000            178.000000       178.000000
# mean        2.295112    2.029270              0.361854         1.590899
# std         0.625851    0.998859              0.124453         0.572359
# ...

# %%
df.isna().sum()
# Out:
# alcohol                         0
# malic_acid                      0
# ash                             0
# alcalinity_of_ash               0
# magnesium                       0
# total_phenols                   0
# flavanoids                      0
# nonflavanoid_phenols            0
# proanthocyanins                 0
# color_intensity                 0
# hue                             0
# od280/od315_of_diluted_wines    0
# proline                         0
# target                          0
# dtype: int64

# %% [markdown]
# There are no missing or null values in the dataset.

# %%
df.corr()
# Out:
#                                alcohol  malic_acid       ash  \
# alcohol                       1.000000    0.094397  0.211545
# malic_acid                    0.094397    1.000000  0.164045
# ash                           0.211545    0.164045  1.000000
# alcalinity_of_ash            -0.310235    0.288500  0.443367
# magnesium                     0.270798   -0.054575  0.286587
# total_phenols                 0.289101   -0.335167  0.128980
# flavanoids                    0.236815   -0.411007  0.115077
# nonflavanoid_phenols         -0.155929    0.292977  0.186230
# proanthocyanins               0.136698   -0.220746  0.009652
# color_intensity               0.546364    0.248985  0.258887
# hue                          -0.071747   -0.561296 -0.074667
# od280/od315_of_diluted_wines  0.072343   -0.368710  0.003911
# proline                       0.643720   -0.192011  0.223626
# target                       -0.328222    0.437776 -0.049643
#
# ...

# %% [markdown]
# ## Countplot - To understand the frequencies for different wine classes

# %%
sns.countplot(x='target', data=df, hue='target');

# %% [markdown]
# ## Scatterplot - To understand the distribution of wine classes

# %%
# Create an array of numbers
numbers = np.arange(df.shape[0])

fig, axes = plt.subplots(nrows=13, ncols=2, figsize=(16, 40), squeeze=False)

for i, column in enumerate(df.columns, start = 0):
    if column != "target":
        sns.scatterplot(x=column, y=numbers, data=df, hue='target', ax=axes[i, 0])
        sns.scatterplot(x=column, y='target', data=df, hue='target', ax=axes[i, 1])
        
fig.tight_layout(pad=3.0)

# %% [markdown]
# ## Box plot - To realize whether there are outliers in each feature

# %%
fig, axes = plt.subplots(nrows=13, ncols=1, figsize=(16, 40), squeeze=False)

for i, column in enumerate(df.columns, start = 0):
    if column != "target":
        sns.boxplot(x=column, data=df, orient='h', palette='Set2', ax=axes[i, 0])
        
fig.tight_layout(pad=3.0);

# %%
df_class0 = df[df['target'] == 0]
df_class1 = df[df['target'] == 1]
df_class2 = df[df['target'] == 2]

# %%
df_class0.shape
# Out:
# (59, 14)

# %% [markdown]
# There are 59 tuples for the wine class 0.

# %%
df_class0.describe()
# Out:
#          alcohol  malic_acid        ash  alcalinity_of_ash   magnesium  \
# count  59.000000   59.000000  59.000000          59.000000   59.000000
# mean   13.744746    2.010678   2.455593          17.037288  106.338983
# std     0.462125    0.688549   0.227166           2.546322   10.498949
# min    12.850000    1.350000   2.040000          11.200000   89.000000
# 25%    13.400000    1.665000   2.295000          16.000000   98.000000
# 50%    13.750000    1.770000   2.440000          16.800000  104.000000
# 75%    14.100000    1.935000   2.615000          18.700000  114.000000
# max    14.830000    4.040000   3.220000          25.000000  132.000000
#
#        total_phenols  flavanoids  nonflavanoid_phenols  proanthocyanins  \
# count      59.000000   59.000000             59.000000        59.000000
# mean        2.840169    2.982373              0.290000         1.899322
# std         0.338961    0.397494              0.070049         0.412109
# ...

# %%
df_class1.shape
# Out:
# (71, 14)

# %% [markdown]
# There are 71 tuples for the wine class 1.

# %%
df_class1.describe()
# Out:
#          alcohol  malic_acid        ash  alcalinity_of_ash   magnesium  \
# count  71.000000   71.000000  71.000000          71.000000   71.000000
# mean   12.278732    1.932676   2.244789          20.238028   94.549296
# std     0.537964    1.015569   0.315467           3.349770   16.753497
# min    11.030000    0.740000   1.360000          10.600000   70.000000
# 25%    11.915000    1.270000   2.000000          18.000000   85.500000
# 50%    12.290000    1.610000   2.240000          20.000000   88.000000
# 75%    12.515000    2.145000   2.420000          22.000000   99.500000
# max    13.860000    5.800000   3.230000          30.000000  162.000000
#
#        total_phenols  flavanoids  nonflavanoid_phenols  proanthocyanins  \
# count      71.000000   71.000000             71.000000        71.000000
# mean        2.258873    2.080845              0.363662         1.630282
# std         0.545361    0.705701              0.123961         0.602068
# ...

# %%
df_class2.shape
# Out:
# (48, 14)

# %% [markdown]
# There are 48 tuples for the wine class 2.

# %%
df_class2.describe()
# Out:
#          alcohol  malic_acid        ash  alcalinity_of_ash   magnesium  \
# count  48.000000   48.000000  48.000000          48.000000   48.000000
# mean   13.153750    3.333750   2.437083          21.416667   99.312500
# std     0.530241    1.087906   0.184690           2.258161   10.890473
# min    12.200000    1.240000   2.100000          17.500000   80.000000
# 25%    12.805000    2.587500   2.300000          20.000000   89.750000
# 50%    13.165000    3.265000   2.380000          21.000000   97.000000
# 75%    13.505000    3.957500   2.602500          23.000000  106.000000
# max    14.340000    5.650000   2.860000          27.000000  123.000000
#
#        total_phenols  flavanoids  nonflavanoid_phenols  proanthocyanins  \
# count      48.000000   48.000000              48.00000        48.000000
# mean        1.678750    0.781458               0.44750         1.153542
# std         0.356971    0.293504               0.12414         0.408836
# ...

# %% [markdown]
# ## Histogram - To understand the distribution of each feature for wine class 0

# %%
fig, axes = plt.subplots(nrows=13, ncols=1, figsize=(16, 50), squeeze=False)

for i, column in enumerate(df_class0.columns, start = 0):
    if column != "target":
        sns.histplot(x=column, data=df_class0, ax=axes[i, 0], kde=True)
        
fig.tight_layout(pad=3.0)

# %% [markdown]
# ## Boxplot - To understand the outliers for each feature for wine class 0

# %%
fig, axes = plt.subplots(nrows=13, ncols=1, figsize=(16, 40), squeeze=False)

for i, column in enumerate(df.columns, start = 0):
    if column != "target":
        sns.boxplot(x=column, data=df_class0, orient='h', palette='Set2', ax=axes[i, 0])
        
fig.tight_layout(pad=3.0);

# %% [markdown]
# ## Histogram - To understand the distribution of each feature for wine class 1

# %%
fig, axes = plt.subplots(nrows=13, ncols=1, figsize=(16, 50), squeeze=False)

for i, column in enumerate(df_class1.columns, start = 0):
    if column != "target":
        sns.histplot(x=column, data=df_class1, ax=axes[i, 0], kde=True)
        
fig.tight_layout(pad=3.0)

# %% [markdown]
# ## Boxplot - To understand the outliers for each feature for wine class 1

# %%
fig, axes = plt.subplots(nrows=13, ncols=1, figsize=(16, 40), squeeze=False)

for i, column in enumerate(df.columns, start = 0):
    if column != "target":
        sns.boxplot(x=column, data=df_class1, orient='h', palette='Set2', ax=axes[i, 0])
        
fig.tight_layout(pad=3.0);

# %% [markdown]
# ## Histogram - To understand the distribution of each feature for wine class 1

# %%
fig, axes = plt.subplots(nrows=13, ncols=1, figsize=(16, 50), squeeze=False)

for i, column in enumerate(df_class2.columns, start = 0):
    if column != "target":
        sns.histplot(x=column, data=df_class2, ax=axes[i, 0], kde=True)
        
fig.tight_layout(pad=3.0)

# %% [markdown]
# ## Boxplot - To understand the outliers for each feature for wine class 2

# %%
fig, axes = plt.subplots(nrows=13, ncols=1, figsize=(16, 40), squeeze=False)

for i, column in enumerate(df.columns, start = 0):
    if column != "target":
        sns.boxplot(x=column, data=df_class2, orient='h', palette='Set2', ax=axes[i, 0])
        
fig.tight_layout(pad=3.0);

# %% [markdown]
# ## Correlation Matrix

# %%
plt.figure(figsize=(16,8))
sns.heatmap(data=df.corr(), annot=True, cmap='coolwarm');

# %%
sns.heatmap(data=pd.DataFrame(df.corr()[df.corr()['target'] > 0]['target']));

# %% [markdown]
# As we can see there is positive correlation between `color_intensity`, `nonflavanoid_phenols`, `alcalinity_of_ash`, `malic_acid`.
